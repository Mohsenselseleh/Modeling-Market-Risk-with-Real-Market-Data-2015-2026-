# %%
# ═══════════════════════════════════════════════════════════════════════════
# RUN THE FULL MARKET RISK ANALYSIS (YAHOO FINANCE DATA)
# ═══════════════════════════════════════════════════════════════════════════

# 1) Install dependencies (run once per runtime)
# !pip install -q yfinance matplotlib pandas scipy

# 2) Run the analysis
#    Assumes your full script (with load_data, risk functions, fig1/fig2/fig3, and main())
#    has already been executed in this notebook.
print("\n" + "="*65)
print("  RUNNING CHAPTER 5 — MODELING MARKET RISK")
print("="*65 + "\n")

main()  # <-- this calls your full pipeline and saves PNGs into outputs/

# 3) Display all generated figures
from IPython.display import Image, display
import os

print("\n" + "="*65)
print("  📊 DISPLAYING ALL OUTPUT FIGURES")
print("="*65 + "\n")

output_dir = "outputs"
if os.path.exists(output_dir):
    png_files = sorted([f for f in os.listdir(output_dir) if f.endswith('.png')])

    if png_files:
        for fname in png_files:
            filepath = os.path.join(output_dir, fname)
            print(f"📁 {fname}")
            display(Image(filename=filepath, width=900))
            print("\n" + "-"*65 + "\n")
    else:
        print("❌ No PNG files found in outputs/")
        print("   Check if main() ran successfully and saved the figures.")
else:
    print("❌ outputs/ folder not found")
    print("   Make sure main() creates the 'outputs' directory and saves the PNGs there.")
# Out:
# ...
#   RUNNING CHAPTER 5 — MODELING MARKET RISK
# ...
#
# ...
#   CHAPTER 5 — MODELING MARKET RISK  (YAHOO FINANCE DATA)
# ...
#
# [1] Loading data …
#     Reading real_prices.csv (Yahoo Finance real data) …
#     2865 days  |  2015-01-02 → 2026-05-26
#     • Annual vol  : 21.14%
#
# [2] Variance-Covariance VaR …
#     • σ_p daily   = 1.3316%
#     • VaR 95%(VC) = $ 20,972.03
#     • VaR 99%(VC) = $ 30,047.10
#
# [3] Historical Simulation VaR …
#     • VaR 95%(HS) = $ 20,226.99
#     • VaR 99%(HS) = $ 39,056.83
#
# [4] Monte Carlo VaR (200,000 paths) …
#     • VaR 99%(MC) = $ 29,852.67
#
# [5] Denoising (Random Matrix Theory) …
#     • λ+          = 1.0853
#     • λ-          = 0.9182
#
# [6] Expected Shortfall …
#     • ES 95%      = $ 31,440.34
#     • ES 99%      = $ 50,982.65
#
# [7] Liquidity-Adjusted ES …
#     • Liq. cost   = $    270.12
#     • LES 99%     = $ 51,252.78
#
# [8] Effective Cost …
#     • Spread      = $    540.00
#     • Impact      = $    115.24
# ...
